# %% [markdown]
# # 1. Import and Install Dependencies

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp

# %% [markdown]
# # 2. Keypoints using MP Holistic

# %%
mp_pose = mp.solutions.pose # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

# %%
def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS) # Draw face connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS) # Draw pose connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw right hand connections

# %%
def draw_styled_landmarks(image, results):
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             )

# %%
def extract_keypoints(results):
    target_indedices=[11,12,13,14,15,16,25,26,27,28,29,30,31,32]
    pose = np.array([[results.pose_landmarks.landmark[index].x, results.pose_landmarks.landmark[index].y, results.pose_landmarks.landmark[index].z, results.pose_landmarks.landmark[index].visibility] for index in target_indedices]).flatten() if results.pose_landmarks else np.zeros(len(target_indedices)*4)
    return pose

# %% [markdown]
# # 4. Setup Folders for Collection

# %%
# Path for exported data, numpy arrays
DATA_PATH = os.path.join('MP_Data') 

# Actions that we try to detect
actions = np.array(['left_shot', 'right_shot', 'head'])

# Thirty videos worth of data
no_sequences = 15

# Videos are going to be 30 frames in length
sequence_length = 15

# Folder start
start_folder = 1

# %%
#create directory
# import shutil
# for action in actions:
        #shutil.rmtree(os.path.join(DATA_PATH, action));
        #os.makedirs(os.path.join(DATA_PATH, action),exist_ok=True)

# %%
print(max([int(f) for f in os.listdir(os.path.join(DATA_PATH, action)) if not f.startswith('.')]))
# Out:
# 31

# %%
start_folder=max([int(f) for f in os.listdir(os.path.join(DATA_PATH, action)) if not f.startswith('.')])+1
print(start_folder)
# Out:
# 32

# %% [markdown]
# # 5. Collect Keypoint Values for Training and Testing

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    
    # NEW LOOP
    # Loop through actions
    for action in actions:
        # Loop through sequences aka videos
        start_folder=max([int(f) for f in os.listdir(os.path.join(DATA_PATH, action)) if not f.startswith('.')])+1
        for sequence in range(start_folder, start_folder+no_sequences):
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
            # Loop through video length aka sequence length
            for frame_num in range(sequence_length):

                # Read feed
                ret, frame = cap.read()

                # Make detections
                image, results = mediapipe_detection(frame, pose)

                # Draw landmarks
                draw_styled_landmarks(image, results)
                
                # NEW Apply wait logic
                if frame_num == 0: 
                    cv2.putText(image, 'STARTING COLLECTION', (120,200), 
                               cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(7000)
                else: 
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                
                # NEW Export keypoints
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints)

                # Break gracefully
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break
                    
    cap.release()
    cv2.destroyAllWindows()

# %%
cap.release()
cv2.destroyAllWindows()

# %%
for action in actions:
    points=np.load(os.path.join(DATA_PATH, action,'1','0.npy'));
    print(len(points))
    break
# Out:
# 56

# %% [markdown]
# # 6. Preprocess Data and Create Labels and Features

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
label_map
# Out:
# {'left_shot': 0, 'right_shot': 1, 'head': 2}

# %%
sequences, labels = [], []
for action in actions:
    for sequence in np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
np.array(sequences).shape
# Out:
# (90, 30, 56)

# %%
np.array(labels).shape
# Out:
# (90,)

# %%
X = np.array(sequences)

# %%
X.shape
# Out:
# (90, 30, 56)

# %%
y = to_categorical(labels).astype(int)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

# %%
y_test.shape
# Out:
# (5, 3)

# %% [markdown]
# # 7. Build and Train LSTM Neural Network

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,56)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(X_train, y_train, epochs=2000, callbacks=[tb_callback])
# Out:
# Epoch 1/2000
# 3/3 [==============================] - 4s 28ms/step - loss: 1.1105 - categorical_accuracy: 0.3294
# Epoch 2/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 1.0961 - categorical_accuracy: 0.3294
# Epoch 3/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 1.0973 - categorical_accuracy: 0.3412
# Epoch 4/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 1.0871 - categorical_accuracy: 0.3412
# Epoch 5/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 1.0750 - categorical_accuracy: 0.3529
# Epoch 6/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 1.0520 - categorical_accuracy: 0.3529
# Epoch 7/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.9826 - categorical_accuracy: 0.4941
# Epoch 8/2000
# 3/3 [==============================] - 0s 26ms/step - loss: 1.6682 - categorical_accuracy: 0.5882
# Epoch 9/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 1.4844 - categorical_accuracy: 0.3294
# Epoch 10/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 1.1096 - categorical_accuracy: 0.3294
# Epoch 11/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 1.1000 - categorical_accuracy: 0.3294
# Epoch 12/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 1.0853 - categorical_accuracy: 0.3412
# Epoch 13/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 1.0709 - categorical_accuracy: 0.5059
# Epoch 14/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 1.0602 - categorical_accuracy: 0.6353
# Epoch 15/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 1.0491 - categorical_accuracy: 0.6353
# Epoch 16/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 1.0249 - categorical_accuracy: 0.6353
# Epoch 17/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.9753 - categorical_accuracy: 0.6353
# Epoch 18/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.7876 - categorical_accuracy: 0.6353
# Epoch 19/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.8422 - categorical_accuracy: 0.6471
# Epoch 20/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.7670 - categorical_accuracy: 0.7529
# Epoch 21/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.7907 - categorical_accuracy: 0.5529
# Epoch 22/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.6995 - categorical_accuracy: 0.6000
# Epoch 23/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.5840 - categorical_accuracy: 0.8588
# Epoch 24/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.5360 - categorical_accuracy: 0.7529
# Epoch 25/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.6084 - categorical_accuracy: 0.6824
# Epoch 26/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 1.5391 - categorical_accuracy: 0.4235
# Epoch 27/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 1.0691 - categorical_accuracy: 0.3412
# Epoch 28/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 1.0330 - categorical_accuracy: 0.3412
# Epoch 29/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 1.0227 - categorical_accuracy: 0.6118
# Epoch 30/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 1.0143 - categorical_accuracy: 0.6235
# Epoch 31/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.9861 - categorical_accuracy: 0.4588
# Epoch 32/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.9413 - categorical_accuracy: 0.3647
# Epoch 33/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.9285 - categorical_accuracy: 0.4353
# Epoch 34/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.9090 - categorical_accuracy: 0.5059
# Epoch 35/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.8238 - categorical_accuracy: 0.6235
# Epoch 36/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 1.6095 - categorical_accuracy: 0.3529
# Epoch 37/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 1.0060 - categorical_accuracy: 0.4706
# Epoch 38/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 1.0006 - categorical_accuracy: 0.3529
# Epoch 39/2000
# 3/3 [==============================] - 0s 24ms/step - loss: 1.0214 - categorical_accuracy: 0.3529
# Epoch 40/2000
# 3/3 [==============================] - 0s 24ms/step - loss: 1.0263 - categorical_accuracy: 0.3529
# Epoch 41/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 1.0239 - categorical_accuracy: 0.3765
# Epoch 42/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 1.0100 - categorical_accuracy: 0.4000
# Epoch 43/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.9875 - categorical_accuracy: 0.3765
# Epoch 44/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.9455 - categorical_accuracy: 0.3765
# Epoch 45/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.8943 - categorical_accuracy: 0.6118
# Epoch 46/2000
# 3/3 [==============================] - 0s 24ms/step - loss: 0.8351 - categorical_accuracy: 0.6588
# Epoch 47/2000
# 3/3 [==============================] - 0s 24ms/step - loss: 0.7497 - categorical_accuracy: 0.6471
# Epoch 48/2000
# 3/3 [==============================] - 0s 24ms/step - loss: 0.8134 - categorical_accuracy: 0.7059
# Epoch 49/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.6810 - categorical_accuracy: 0.7059
# Epoch 50/2000
# 3/3 [==============================] - 0s 24ms/step - loss: 0.5300 - categorical_accuracy: 0.8353
# Epoch 51/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.5336 - categorical_accuracy: 0.7647
# Epoch 52/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.4507 - categorical_accuracy: 0.9059
# Epoch 53/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.5275 - categorical_accuracy: 0.7176
# Epoch 54/2000
# 3/3 [==============================] - 0s 24ms/step - loss: 0.4940 - categorical_accuracy: 0.8353
# Epoch 55/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.3667 - categorical_accuracy: 0.8824
# Epoch 56/2000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.4023 - categorical_accuracy: 0.8824
# Epoch 57/2000
# 3/3 [==============================] - 0s 24ms/step - loss: 0.3601 - categorical_accuracy: 0.8588
# Epoch 58/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.4808 - categorical_accuracy: 0.8118
# Epoch 59/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.5948 - categorical_accuracy: 0.7176
# Epoch 60/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.4995 - categorical_accuracy: 0.7765
# Epoch 61/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.4583 - categorical_accuracy: 0.7412
# Epoch 62/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.4120 - categorical_accuracy: 0.8706
# Epoch 63/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.3956 - categorical_accuracy: 0.8588
# Epoch 64/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.3313 - categorical_accuracy: 0.9294
# Epoch 65/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.3014 - categorical_accuracy: 0.9412
# Epoch 66/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.2497 - categorical_accuracy: 0.9294
# Epoch 67/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.2852 - categorical_accuracy: 0.9294
# Epoch 68/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.2897 - categorical_accuracy: 0.8941
# Epoch 69/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.2355 - categorical_accuracy: 0.9529
# Epoch 70/2000
# 3/3 [==============================] - 0s 24ms/step - loss: 0.2123 - categorical_accuracy: 0.9412
# Epoch 71/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.2277 - categorical_accuracy: 0.9176
# Epoch 72/2000
# 3/3 [==============================] - 0s 24ms/step - loss: 0.3214 - categorical_accuracy: 0.8941
# Epoch 73/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.2029 - categorical_accuracy: 0.9412
# Epoch 74/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.3163 - categorical_accuracy: 0.9176
# Epoch 75/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.5748 - categorical_accuracy: 0.7176
# Epoch 76/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.6701 - categorical_accuracy: 0.6471
# Epoch 77/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.6047 - categorical_accuracy: 0.6824
# Epoch 78/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.4883 - categorical_accuracy: 0.9294
# Epoch 79/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.6082 - categorical_accuracy: 0.7882
# Epoch 80/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.6803 - categorical_accuracy: 0.7176
# Epoch 81/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.5647 - categorical_accuracy: 0.8235
# Epoch 82/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.4157 - categorical_accuracy: 0.9176
# Epoch 83/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.4520 - categorical_accuracy: 0.8353
# Epoch 84/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.4102 - categorical_accuracy: 0.8941
# Epoch 85/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.3584 - categorical_accuracy: 0.8706
# Epoch 86/2000
# 3/3 [==============================] - 0s 24ms/step - loss: 0.2773 - categorical_accuracy: 0.9294
# Epoch 87/2000
# 3/3 [==============================] - 0s 24ms/step - loss: 0.3090 - categorical_accuracy: 0.9059
# Epoch 88/2000
# 3/3 [==============================] - 0s 25ms/step - loss: 0.4537 - categorical_accuracy: 0.8235
# Epoch 89/2000
# 3/3 [==============================] - 0s 24ms/step - loss: 0.2576 - categorical_accuracy: 0.9059
# Epoch 90/2000
# 3/3 [==============================] - 0s 24ms/step - loss: 0.2959 - categorical_accuracy: 0.9176
# Epoch 91/2000
# 3/3 [==============================] - 0s 25ms/step - loss: 0.4162 - categorical_accuracy: 0.8706
# Epoch 92/2000
# 3/3 [==============================] - 0s 24ms/step - loss: 0.3268 - categorical_accuracy: 0.9176
# Epoch 93/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.2716 - categorical_accuracy: 0.9059
# Epoch 94/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.2254 - categorical_accuracy: 0.9647
# Epoch 95/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.2700 - categorical_accuracy: 0.9294
# Epoch 96/2000
# 3/3 [==============================] - 0s 24ms/step - loss: 0.2094 - categorical_accuracy: 0.9647
# Epoch 97/2000
# 3/3 [==============================] - 0s 25ms/step - loss: 0.1940 - categorical_accuracy: 0.9294
# Epoch 98/2000
# 3/3 [==============================] - 0s 28ms/step - loss: 0.2151 - categorical_accuracy: 0.9412
# Epoch 99/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.2071 - categorical_accuracy: 0.9412
# Epoch 100/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1368 - categorical_accuracy: 0.9647
# Epoch 101/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1382 - categorical_accuracy: 0.9765
# Epoch 102/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1313 - categorical_accuracy: 0.9765
# Epoch 103/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1180 - categorical_accuracy: 0.9765
# Epoch 104/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1073 - categorical_accuracy: 0.9647
# Epoch 105/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1100 - categorical_accuracy: 0.9529
# Epoch 106/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.3863 - categorical_accuracy: 0.8353
# Epoch 107/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.5907 - categorical_accuracy: 0.8118
# Epoch 108/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.5687 - categorical_accuracy: 0.7765
# Epoch 109/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.2606 - categorical_accuracy: 0.9059
# Epoch 110/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.3806 - categorical_accuracy: 0.8941
# Epoch 111/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.3626 - categorical_accuracy: 0.8706
# Epoch 112/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.3358 - categorical_accuracy: 0.8824
# Epoch 113/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.2688 - categorical_accuracy: 0.9294
# Epoch 114/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.2510 - categorical_accuracy: 0.9412
# Epoch 115/2000
# 3/3 [==============================] - 0s 24ms/step - loss: 0.2247 - categorical_accuracy: 0.9412
# Epoch 116/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1961 - categorical_accuracy: 0.9529
# Epoch 117/2000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1553 - categorical_accuracy: 0.9529
# Epoch 118/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1437 - categorical_accuracy: 0.9412
# Epoch 119/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1509 - categorical_accuracy: 0.9529
# Epoch 120/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1548 - categorical_accuracy: 0.9412
# Epoch 121/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1734 - categorical_accuracy: 0.9412
# Epoch 122/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.2350 - categorical_accuracy: 0.9412
# Epoch 123/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1300 - categorical_accuracy: 0.9412
# Epoch 124/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1612 - categorical_accuracy: 0.9176
# Epoch 125/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1657 - categorical_accuracy: 0.9412
# Epoch 126/2000
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1136 - categorical_accuracy: 0.9647
# Epoch 127/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1268 - categorical_accuracy: 0.9529
# Epoch 128/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1004 - categorical_accuracy: 0.9765
# Epoch 129/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0985 - categorical_accuracy: 0.9765
# Epoch 130/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0910 - categorical_accuracy: 0.9765
# Epoch 131/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0901 - categorical_accuracy: 0.9765
# Epoch 132/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0872 - categorical_accuracy: 0.9765
# Epoch 133/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0845 - categorical_accuracy: 0.9765
# Epoch 134/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0789 - categorical_accuracy: 0.9765
# Epoch 135/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0758 - categorical_accuracy: 0.9765
# Epoch 136/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0815 - categorical_accuracy: 0.9765
# Epoch 137/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0699 - categorical_accuracy: 0.9765
# Epoch 138/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1099 - categorical_accuracy: 0.9647
# Epoch 139/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.2523 - categorical_accuracy: 0.9294
# Epoch 140/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1579 - categorical_accuracy: 0.9412
# Epoch 141/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1786 - categorical_accuracy: 0.9294
# Epoch 142/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1537 - categorical_accuracy: 0.9412
# Epoch 143/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1830 - categorical_accuracy: 0.9412
# Epoch 144/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1683 - categorical_accuracy: 0.9412
# Epoch 145/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1142 - categorical_accuracy: 0.9765
# Epoch 146/2000
# 3/3 [==============================] - 0s 31ms/step - loss: 0.1396 - categorical_accuracy: 0.9412
# Epoch 147/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1323 - categorical_accuracy: 0.9529
# Epoch 148/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1045 - categorical_accuracy: 0.9765
# Epoch 149/2000
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0973 - categorical_accuracy: 0.9765
# Epoch 150/2000
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0997 - categorical_accuracy: 0.9647
# Epoch 151/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0895 - categorical_accuracy: 0.9647
# Epoch 152/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0842 - categorical_accuracy: 0.9765
# Epoch 153/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0839 - categorical_accuracy: 0.9765
# Epoch 154/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0789 - categorical_accuracy: 0.9765
# Epoch 155/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0789 - categorical_accuracy: 0.9765
# Epoch 156/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0779 - categorical_accuracy: 0.9765
# Epoch 157/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0743 - categorical_accuracy: 0.9765
# Epoch 158/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0762 - categorical_accuracy: 0.9765
# Epoch 159/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0705 - categorical_accuracy: 0.9765
# Epoch 160/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0741 - categorical_accuracy: 0.9765
# Epoch 161/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0680 - categorical_accuracy: 0.9765
# Epoch 162/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0900 - categorical_accuracy: 0.9647
# Epoch 163/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0692 - categorical_accuracy: 0.9765
# Epoch 164/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0665 - categorical_accuracy: 0.9765
# Epoch 165/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0634 - categorical_accuracy: 0.9765
# Epoch 166/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0648 - categorical_accuracy: 0.9765
# Epoch 167/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0667 - categorical_accuracy: 0.9765
# Epoch 168/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0631 - categorical_accuracy: 0.9765
# Epoch 169/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0669 - categorical_accuracy: 0.9882
# Epoch 170/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0732 - categorical_accuracy: 0.9765
# Epoch 171/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0611 - categorical_accuracy: 0.9882
# Epoch 172/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0548 - categorical_accuracy: 0.9882
# Epoch 173/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0578 - categorical_accuracy: 0.9765
# Epoch 174/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0517 - categorical_accuracy: 0.9882
# Epoch 175/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0536 - categorical_accuracy: 0.9882
# Epoch 176/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0512 - categorical_accuracy: 0.9882
# Epoch 177/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0512 - categorical_accuracy: 0.9882
# Epoch 178/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0468 - categorical_accuracy: 0.9882
# Epoch 179/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0462 - categorical_accuracy: 0.9882
# Epoch 180/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0452 - categorical_accuracy: 0.9882
# Epoch 181/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0451 - categorical_accuracy: 0.9882
# Epoch 182/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0446 - categorical_accuracy: 0.9882
# Epoch 183/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0408 - categorical_accuracy: 0.9882
# Epoch 184/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0403 - categorical_accuracy: 0.9882
# Epoch 185/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0419 - categorical_accuracy: 0.9882
# Epoch 186/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0409 - categorical_accuracy: 0.9882
# Epoch 187/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0394 - categorical_accuracy: 0.9882
# Epoch 188/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0375 - categorical_accuracy: 0.9882
# Epoch 189/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0378 - categorical_accuracy: 0.9882
# Epoch 190/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0367 - categorical_accuracy: 0.9882
# Epoch 191/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0365 - categorical_accuracy: 0.9882
# Epoch 192/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0367 - categorical_accuracy: 0.9882
# Epoch 193/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0362 - categorical_accuracy: 0.9882
# Epoch 194/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0345 - categorical_accuracy: 0.9882
# Epoch 195/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0353 - categorical_accuracy: 0.9882
# Epoch 196/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0346 - categorical_accuracy: 0.9882
# Epoch 197/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0341 - categorical_accuracy: 0.9882
# Epoch 198/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0347 - categorical_accuracy: 0.9882
# Epoch 199/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0334 - categorical_accuracy: 0.9882
# Epoch 200/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0338 - categorical_accuracy: 0.9882
# Epoch 201/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0325 - categorical_accuracy: 0.9882
# Epoch 202/2000
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0324 - categorical_accuracy: 0.9882
# Epoch 203/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0321 - categorical_accuracy: 0.9882
# Epoch 204/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0325 - categorical_accuracy: 0.9882
# Epoch 205/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0333 - categorical_accuracy: 0.9882
# Epoch 206/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0335 - categorical_accuracy: 0.9882
# Epoch 207/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0339 - categorical_accuracy: 0.9882
# Epoch 208/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0310 - categorical_accuracy: 0.9882
# Epoch 209/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0476 - categorical_accuracy: 0.9765
# Epoch 210/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1916 - categorical_accuracy: 0.9647
# Epoch 211/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 3.7311 - categorical_accuracy: 0.6588
# Epoch 212/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 1.4316 - categorical_accuracy: 0.5176
# Epoch 213/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 1.1529 - categorical_accuracy: 0.3765
# Epoch 214/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.8959 - categorical_accuracy: 0.4706
# Epoch 215/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 1.1646 - categorical_accuracy: 0.7294
# Epoch 216/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 1.0500 - categorical_accuracy: 0.6824
# Epoch 217/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.9153 - categorical_accuracy: 0.6588
# Epoch 218/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.8820 - categorical_accuracy: 0.6353
# Epoch 219/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.8120 - categorical_accuracy: 0.6588
# Epoch 220/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.7360 - categorical_accuracy: 0.6824
# Epoch 221/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.6457 - categorical_accuracy: 0.7294
# Epoch 222/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.5434 - categorical_accuracy: 0.8000
# Epoch 223/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.5157 - categorical_accuracy: 0.8118
# Epoch 224/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 1.1987 - categorical_accuracy: 0.4000
# Epoch 225/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.5667 - categorical_accuracy: 0.8353
# Epoch 226/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.5954 - categorical_accuracy: 0.8706
# Epoch 227/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.5923 - categorical_accuracy: 0.9294
# Epoch 228/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.6030 - categorical_accuracy: 0.9294
# Epoch 229/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.5782 - categorical_accuracy: 0.9294
# Epoch 230/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.5356 - categorical_accuracy: 0.9294
# Epoch 231/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.4861 - categorical_accuracy: 0.9059
# Epoch 232/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.4326 - categorical_accuracy: 0.9176
# Epoch 233/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.3864 - categorical_accuracy: 0.9412
# Epoch 234/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.3372 - categorical_accuracy: 0.9412
# Epoch 235/2000
# 3/3 [==============================] - 0s 24ms/step - loss: 0.3020 - categorical_accuracy: 0.9412
# Epoch 236/2000
# 3/3 [==============================] - 0s 24ms/step - loss: 0.2976 - categorical_accuracy: 0.9412
# Epoch 237/2000
# 3/3 [==============================] - 0s 24ms/step - loss: 0.2926 - categorical_accuracy: 0.9412
# Epoch 238/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.2606 - categorical_accuracy: 0.9412
# Epoch 239/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.2677 - categorical_accuracy: 0.9529
# Epoch 240/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.2598 - categorical_accuracy: 0.9294
# Epoch 241/2000
# 3/3 [==============================] - 0s 24ms/step - loss: 0.2662 - categorical_accuracy: 0.9294
# Epoch 242/2000
# 3/3 [==============================] - 0s 25ms/step - loss: 0.2378 - categorical_accuracy: 0.9412
# Epoch 243/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.2415 - categorical_accuracy: 0.9412
# Epoch 244/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.2284 - categorical_accuracy: 0.9412
# Epoch 245/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.2291 - categorical_accuracy: 0.9529
# Epoch 246/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.2113 - categorical_accuracy: 0.9412
# Epoch 247/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.2192 - categorical_accuracy: 0.9412
# Epoch 248/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.2133 - categorical_accuracy: 0.9412
# Epoch 249/2000
# 3/3 [==============================] - 0s 22ms/step - loss: 0.1982 - categorical_accuracy: 0.9529
# Epoch 250/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.2056 - categorical_accuracy: 0.9412
# Epoch 251/2000
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1871 - categorical_accuracy: 0.9529
# Epoch 252/2000
# 3/3 [==============================] - 0s 23ms/step - loss: 0.1773 - categorical_accuracy: 0.9529
# Epoch 253/2000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.
#
# File ~/anaconda3/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py:2620, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2611     except ValueError:
#    2612         warnings.warn(
#    2613             "Using Model.predict with MultiWorkerMirroredStrategy "
#    2614             "or TPUStrategy and AutoShardPolicy.FILE might lead to "
#    (...)
#    2617             stacklevel=2,
#    2618         )
# -> 2620 data_handler = data_adapter.get_data_handler(
#    2621     x=x,
#    2622     batch_size=batch_size,
#    2623     steps_per_epoch=steps,
#    2624     initial_epoch=0,
#    2625     epochs=1,
#    2626     max_queue_size=max_queue_size,
#    2627     workers=workers,
#    2628     use_multiprocessing=use_multiprocessing,
#    2629     model=self,
#    2630     steps_per_execution=self._steps_per_execution,
#    2631 )
#    2633 # Container that configures and calls `tf.keras.Callback`s.
#    2634 if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File ~/anaconda3/lib/python3.11/site-packages/keras/src/engine/data_adapter.py:1688, in get_data_handler(*args, **kwargs)
#    1686         return _ClusterCoordinatorExactEvalDataHandler(*args, **kwargs)
#    1687     return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1688 return DataHandler(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/keras/src/engine/data_adapter.py:1292, in DataHandler.__init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute, pss_evaluation_shards)
#    1289     self._steps_per_execution = steps_per_execution
#    1291 adapter_cls = select_data_adapter(x, y)
# -> 1292 self._adapter = adapter_cls(
#    1293     x,
#    1294     y,
#    1295     batch_size=batch_size,
#    1296     steps=steps_per_epoch,
#    1297     epochs=epochs - initial_epoch,
#    1298     sample_weights=sample_weight,
#    1299     shuffle=shuffle,
#    1300     max_queue_size=max_queue_size,
#    1301     workers=workers,
#    1302     use_multiprocessing=use_multiprocessing,
#    1303     distribution_strategy=tf.distribute.get_strategy(),
#    1304     model=model,
#    1305     pss_evaluation_shards=pss_evaluation_shards,
#    1306 )
#    1308 strategy = tf.distribute.get_strategy()
#    1310 self._current_step = 0
#
# File ~/anaconda3/lib/python3.11/site-packages/keras/src/engine/data_adapter.py:355, in TensorLikeDataAdapter.__init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     351     return flat_dataset
#     353 indices_dataset = indices_dataset.flat_map(slice_batch_indices)
# --> 355 dataset = self.slice_inputs(indices_dataset, inputs)
#     357 if shuffle == "batch":
#     359     def shuffle_batch(*batch):
#
# File ~/anaconda3/lib/python3.11/site-packages/keras/src/engine/data_adapter.py:396, in TensorLikeDataAdapter.slice_inputs(self, indices_dataset, inputs)
#     391 def grab_batch(i, data):
#     392     return tf.nest.map_structure(
#     393         lambda d: tf.gather(d, i, axis=0), data
#     394     )
# --> 396 dataset = dataset.map(grab_batch, num_parallel_calls=tf.data.AUTOTUNE)
#     398 # Default optimizations are disabled to avoid the overhead of
#     399 # (unnecessary) input pipeline graph serialization and deserialization
#     400 options = tf.data.Options()
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/data/ops/dataset_ops.py:2280, in DatasetV2.map(self, map_func, num_parallel_calls, deterministic, name)
#    2276 # Loaded lazily due to a circular dependency (dataset_ops -> map_op ->
#    2277 # dataset_ops).
#    2278 # pylint: disable=g-import-not-at-top,protected-access
#    2279 from tensorflow.python.data.ops import map_op
# -> 2280 return map_op._map_v2(
#    2281     self,
#    2282     map_func,
#    2283     num_parallel_calls=num_parallel_calls,
#    2284     deterministic=deterministic,
#    2285     name=name)
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/data/ops/map_op.py:40, in _map_v2(input_dataset, map_func, num_parallel_calls, deterministic, name)
#      37   return _MapDataset(
#      38       input_dataset, map_func, preserve_cardinality=True, name=name)
#      39 else:
# ---> 40   return _ParallelMapDataset(
#      41       input_dataset,
#      42       map_func,
#      43       num_parallel_calls=num_parallel_calls,
#      44       deterministic=deterministic,
#      45       preserve_cardinality=True,
#      46       name=name)
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/data/ops/map_op.py:148, in _ParallelMapDataset.__init__(self, input_dataset, map_func, num_parallel_calls, deterministic, use_inter_op_parallelism, preserve_cardinality, use_legacy_function, name)
#     146 self._input_dataset = input_dataset
#     147 self._use_inter_op_parallelism = use_inter_op_parallelism
# --> 148 self._map_func = structured_function.StructuredFunctionWrapper(
#     149     map_func,
#     150     self._transformation_name(),
#     151     dataset=input_dataset,
#     152     use_legacy_function=use_legacy_function)
#     153 if deterministic is None:
#     154   self._deterministic = "default"
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/data/ops/structured_function.py:265, in StructuredFunctionWrapper.__init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#     258       warnings.warn(
#     259           "Even though the `tf.config.experimental_run_functions_eagerly` "
#     260           "option is set, this option does not apply to tf.data functions. "
#     261           "To force eager execution of tf.data functions, please use "
#     262           "`tf.data.experimental.enable_debug_mode()`.")
#     263     fn_factory = trace_tf_function(defun_kwargs)
# --> 265 self._function = fn_factory()
#     266 # There is no graph to add in eager mode.
#     267 add_to_graph &= not context.executing_eagerly()
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:1227, in Function.get_concrete_function(self, *args, **kwargs)
#    1225 def get_concrete_function(self, *args, **kwargs):
#    1226   # Implements PolymorphicFunction.get_concrete_function.
# -> 1227   concrete = self._get_concrete_function_garbage_collected(*args, **kwargs)
#    1228   concrete._garbage_collector.release()  # pylint: disable=protected-access
#    1229   return concrete
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:1197, in Function._get_concrete_function_garbage_collected(self, *args, **kwargs)
#    1195   if self._variable_creation_config is None:
#    1196     initializers = []
# -> 1197     self._initialize(args, kwargs, add_initializers_to=initializers)
#    1198     self._initialize_uninitialized_variables(initializers)
#    1200 if self._created_variables:
#    1201   # In this case we have created variables on the first call, so we run the
#    1202   # version which is guaranteed to never create variables.
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:695, in Function._initialize(self, args, kwds, add_initializers_to)
#     690 self._variable_creation_config = self._generate_scoped_tracing_options(
#     691     variable_capturing_scope,
#     692     tracing_compilation.ScopeType.VARIABLE_CREATION,
#     693 )
#     694 # Force the definition of the function for these arguments
# --> 695 self._concrete_variable_creation_fn = tracing_compilation.trace_function(
#     696     args, kwds, self._variable_creation_config
#     697 )
#     699 def invalid_creator_scope(*unused_args, **unused_kwds):
#     700   """Disables variable creation."""
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:178, in trace_function(args, kwargs, tracing_options)
#     175     args = tracing_options.input_signature
#     176     kwargs = {}
# --> 178   concrete_function = _maybe_define_function(
#     179       args, kwargs, tracing_options
#     180   )
#     182 if not tracing_options.bind_graph_to_function:
#     183   concrete_function._garbage_collector.release()  # pylint: disable=protected-access
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:283, in _maybe_define_function(args, kwargs, tracing_options)
#     281 else:
#     282   target_func_type = lookup_func_type
# --> 283 concrete_function = _create_concrete_function(
#     284     target_func_type, lookup_func_context, func_graph, tracing_options
#     285 )
#     287 if tracing_options.function_cache is not None:
#     288   tracing_options.function_cache.add(
#     289       concrete_function, current_func_context
#     290   )
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:310, in _create_concrete_function(function_type, type_context, func_graph, tracing_options)
#     303   placeholder_bound_args = function_type.placeholder_arguments(
#     304       placeholder_context
#     305   )
#     307 disable_acd = tracing_options.attributes and tracing_options.attributes.get(
#     308     attributes_lib.DISABLE_ACD, False
#     309 )
# --> 310 traced_func_graph = func_graph_module.func_graph_from_py_func(
#     311     tracing_options.name,
#     312     tracing_options.python_function,
#     313     placeholder_bound_args.args,
#     314     placeholder_bound_args.kwargs,
#     315     None,
#     316     func_graph=func_graph,
#     317     add_control_dependencies=not disable_acd,
#     318     arg_names=function_type_utils.to_arg_names(function_type),
#     319     create_placeholders=False,
#     320 )
#     322 transform.apply_func_graph_transforms(traced_func_graph)
#     324 graph_capture_container = traced_func_graph.function_captures
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/framework/func_graph.py:1017, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#    1011 signature_context = trace_type.InternalTracingContext()
#    1012 # Convert all Tensors into TensorSpecs before saving the structured inputs.
#    1013 # If storing pure concrete functions that are not called through polymorphic
#    1014 # functions, we don't have access to FunctionSpec, so we need to call the
#    1015 # TensorSpecs by their `arg_names` for later binding.
#    1016 func_graph.structured_input_signature = (
# -> 1017     convert_structure_to_signature(
#    1018         func_args, arg_names, signature_context=signature_context),
#    1019     convert_structure_to_signature(
#    1020         func_kwargs, signature_context=signature_context))
#    1022 # Note: `nest.flatten` sorts by keys, as does `_deterministic_dict_values`.
#    1023 # Variables to help check whether mutation happens in calling the function
#    1024 # Copy the recursive list, tuple and map structure, but not base objects
#    1025 func_args_before = nest.pack_sequence_as(
#    1026     func_args,
#    1027     nest.flatten(func_args, expand_composites=True),
#    1028     expand_composites=True)
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/framework/func_graph.py:118, in convert_structure_to_signature(structure, arg_names, signature_context)
#     114   return UnknownArgument()
#     116 # We are using the flattened paths to name the TensorSpecs. We need an
#     117 # explicit name for them downstream.
# --> 118 flattened = nest.flatten_with_tuple_paths(structure)
#     119 if arg_names:
#     120   if len(arg_names) != len(structure):
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/util/nest.py:1286, in flatten_with_tuple_paths(structure, expand_composites)
#    1267 def flatten_with_tuple_paths(structure, expand_composites=False):
#    1268   """Returns a list of `(tuple_path, atom)` tuples.
#    1269
#    1270   The order of pairs produced matches that of `nest.flatten`. This allows you
#    (...)
#    1284     `atom` within `structure`.
#    1285   """
# -> 1286   return list(zip(yield_flat_paths(structure,
#    1287                                    expand_composites=expand_composites),
#    1288                   flatten(structure, expand_composites=expand_composites)))
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/util/nest.py:1232, in yield_flat_paths(nest, expand_composites)
#    1193 """Yields paths for some nested structure.
#    1194
#    1195 Refer to [tf.nest](https://www.tensorflow.org/api_docs/python/tf/nest)
#    (...)
#    1229   leaf value in the nested structure.
#    1230 """
#    1231 is_nested_fn = _is_nested_or_composite if expand_composites else is_nested
# -> 1232 for k, _ in nest_util.yield_flat_up_to(
#    1233     nest_util.Modality.CORE, nest, nest, is_nested_fn
#    1234 ):
#    1235   yield k
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/util/nest_util.py:1161, in yield_flat_up_to(modality, shallow_tree, input_tree, is_nested_fn, path)
#    1139 """Yields (path, value) pairs of input_tree flattened up to shallow_tree.
#    1140
#    1141 - For Modality.CORE: See comments for _tf_core_yield_flat_up_to() below
#    (...)
#    1158   input_tree.
#    1159 """
#    1160 if modality == Modality.CORE:
# -> 1161   yield from _tf_core_yield_flat_up_to(
#    1162       shallow_tree, input_tree, is_nested_fn, path
#    1163   )
#    1164 elif modality == Modality.DATA:
#    1165   yield from _tf_data_yield_flat_up_to(shallow_tree, input_tree)
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/util/nest_util.py:1190, in _tf_core_yield_flat_up_to(shallow_tree, input_tree, is_nested_fn, path)
#    1172 def _tf_core_yield_flat_up_to(shallow_tree, input_tree, is_nested_fn, path=()):
#    1173   """Yields (path, value) pairs of input_tree flattened up to shallow_tree.
#    1174
#    1175   Args:
#    (...)
#    1188     input_tree.
#    1189   """
# -> 1190   if not is_nested_fn(shallow_tree):
#    1191     yield (path, input_tree)
#    1192   else:
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/util/nest.py:179, in is_nested(seq)
#     166 @tf_export("nest.is_nested")
#     167 def is_nested(seq):
#     168   """Returns true if its input is a nested structure.
#     169
#     170   Refer to [tf.nest](https://www.tensorflow.org/api_docs/python/tf/nest)
#    (...)
#     177     True if the input is a nested structure.
#     178   """
# --> 179   return nest_util.is_nested(nest_util.Modality.CORE, seq)
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/util/nest_util.py:150, in is_nested(modality, structure)
#     136 """Returns true if its input is a nested structure.
#     137
#     138 For Modality.CORE refer to
#    (...)
#     147   True if the input is a nested structure.
#     148 """
#     149 if modality == Modality.CORE:
# --> 150   return _tf_core_is_nested(structure)
#     151 elif modality == Modality.DATA:
#     152   return _tf_data_is_nested(structure)
#
# KeyboardInterrupt:
